# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
filename = librosa.util.example_audio_file()

# %%
filename
# Out:
# '/home/max/anaconda3/lib/python3.7/site-packages/librosa/util/example_data/Kevin_MacLeod_-_Vibe_Ace.ogg'

# %%
y, sr = librosa.load(filename)

# %%
ipd.Audio(filename)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
plt.grid()
librosa.display.waveplot(y, sr=sr)

# %%
f = librosa.feature.zero_crossing_rate(y, frame_length=2048, hop_length=512)

# %%
import numpy as np
np.mean(f)
# Out:
# 0.023923752125047222

# %%
stft = np.abs(librosa.stft(y, n_fft=2048, hop_length=512))

# %%
plt.figure(figsize=(16,10))
librosa.display.specshow(librosa.amplitude_to_db(stft, ref=np.max), y_axis='log', x_axis='time')
